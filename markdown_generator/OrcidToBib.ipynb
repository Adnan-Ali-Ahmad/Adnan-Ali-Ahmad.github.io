# %%
orcid = '0009-0004-2719-1107' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()

# %%
'https://pub.orcid.org/v3.0/{}/works'.format(orcid)
# Out:
# 'https://pub.orcid.org/v3.0/0009-0004-2719-1107/works'

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)
put_code = put_codes[0]

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    print(work['citation'])
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])
# Out:
# None
# None
# None
# None
# None
# None
# None
# None

# %%
'https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code)
# Out:
# 'https://pub.orcid.org/v3.0/0009-0004-2719-1107/work/148099441'

# %%
work
# Out:
# {'created-date': {'value': 1701776371294},
#  'last-modified-date': {'value': 1701776371294},
#  'source': {'source-orcid': None,
#   'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#    'path': '0000-0001-9884-1913',
#    'host': 'orcid.org'},
#   'source-name': {'value': 'Crossref'},
#   'assertion-origin-orcid': None,
#   'assertion-origin-client-id': None,
#   'assertion-origin-name': None},
#  'put-code': 148099441,
#  'path': '/0009-0004-2719-1107/work/148099441',
#  'title': {'title': {'value': 'The birth and early evolution of a low-mass protostar'},
#   'subtitle': None,
#   'translated-title': None},
#  'journal-title': {'value': 'Astronomy & Astrophysics'},
#  'short-description': None,
#  'citation': None,
#  'type': 'journal-article',
#  'publication-date': {'year': {'value': '2023'},
#   'month': {'value': '12'},
#   'day': None},
#  'external-ids': {'external-id': [{'external-id-type': 'doi',
#     'external-id-value': '10.1051/0004-6361/202346711',
#     'external-id-normalized': {'value': '10.1051/0004-6361/202346711',
#      'transient': True},
#     'external-id-normalized-error': None,
#     'external-id-url': {'value': 'https://doi.org/10.1051/0004-6361/202346711'},
#     'external-id-relationship': 'self'}]},
#  'url': {'value': 'https://doi.org/10.1051/0004-6361/202346711'},
#  'contributors': {'contributor': [{'contributor-orcid': None,
#     'credit-name': {'value': 'A. Ahmad'},
#     'contributor-email': None,
#     'contributor-attributes': {'contributor-sequence': None,
#      'contributor-role': 'author'}},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'M. González'},
#     'contributor-email': None,
#     'contributor-attributes': {'contributor-sequence': None,
#      'contributor-role': 'author'}},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'P. Hennebelle'},
#     'contributor-email': None,
#     'contributor-attributes': {'contributor-sequence': None,
#      'contributor-role': 'author'}},
#    {'contributor-orcid': None,
#     'credit-name': {'value': 'B. Commerçon'},
#     'contributor-email': None,
#     'contributor-attributes': {'contributor-sequence': None,
#      'contributor-role': 'author'}}]},
#  'language-code': None,
#  'country': None,
#  'visibility': 'public'}

# %%
with open('output.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')
